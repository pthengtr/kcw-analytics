# %%
import os
import sys

if "google.colab" in sys.modules:
    # Running in Colab

    # !git clone https://github.com/pthengtr/kcw-analytics.git
    # !cd /content/kcw-analytics && git pull origin main

    from google.colab import drive
    drive.mount("/content/drive")

    BASE_FOLDER = "/content/drive/Shareddrives"
    BASE_FOLDER_GIT = "/content"
else:
    # Running in local Jupyter
    BASE_FOLDER = r"G:\Shared drives"
    BASE_FOLDER_GIT = r"C:\Users\Windows 11\Notebook"

print("Using folder:", BASE_FOLDER)
# Out:
# Cloning into 'kcw-analytics'...
# remote: Enumerating objects: 650, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 650 (delta 3), reused 3 (delta 1), pack-reused 641 (from 2)
# Receiving objects: 100% (650/650), 528.03 KiB | 2.95 MiB/s, done.
# Resolving deltas: 100% (436/436), done.
# From https://github.com/pthengtr/kcw-analytics
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Mounted at /content/drive
# Using folder: /content/drive/Shareddrives

# %%
from datetime import datetime
import shutil


suffix = datetime.now().strftime("%Y-%m-%d")

folder_to_zip = f"{BASE_FOLDER}/KCW-Data/kcw_analytics/04_outputs"
zip_path = f"{BASE_FOLDER}/KCW-Data/kcw_analytics/06_archive/export_{suffix}"

shutil.make_archive(zip_path, 'zip', folder_to_zip)
# Out:
# '/content/drive/Shareddrives/KCW-Data/kcw_analytics/06_archive/export_2026-03-08.zip'
