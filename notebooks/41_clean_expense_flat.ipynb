# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 29.7 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine(
    "postgresql+psycopg2://postgres.jdzitzsucntqbjvwiwxm:3h3aAixsyK4X762r@aws-0-ap-southeast-1.pooler.supabase.com:5432/postgres"
)

# %%
query = """
SELECT *
FROM public.vw_expense_entry_flat
ORDER BY created_at DESC
"""

df_expense_entries = pd.read_sql(query, engine)

df_expense_entries.head()
# Out:
#                              entry_uuid                          receipt_uuid  \
# 0  d1515651-1c32-4faa-82a2-b313392be78b  f143daec-6f64-49c4-8fc4-fe62fe3b7930
# 1  e790a6dd-624a-45e3-a870-c0413bf06f97  b32209a1-6e95-48d2-bd3a-91364fc4fec5
# 2  92deb645-e9ce-4f6f-8320-0a8f47c34346  fd510101-6f0a-4290-8405-228b836d28bd
# 3  bc860429-5c18-4a7d-a1a4-9df78b323c66  ab3242ba-0c61-4dd9-9ff2-7c68ecafa337
# 4  a954f809-6570-43f2-acd7-01e8b83f9426  f3572d7b-0486-4c9f-9470-8d9684ca6f0d
#
#        receipt_number doc_type ref_receipt_uuid        receipt_date  \
# 0             1002634  RECEIPT             None 2026-02-20 19:49:47
# 1             1002611  RECEIPT             None 2026-02-20 19:49:47
# 2             1002611  RECEIPT             None 2026-02-20 19:49:47
# 3  SI-036847260200163  RECEIPT             None 2026-02-18 19:04:00
# 4        000030743495  RECEIPT             None 2026-02-20 19:04:00
#
#   receipt_day receipt_month_start receipt_month_year  receipt_year  ...  \
# ...

# %%
query = """
SELECT *
FROM public.vw_expense_general_flat
ORDER BY created_at DESC
"""

df_expense_general = pd.read_sql(query, engine)

df_expense_general.head()
# Out:
#                            general_uuid          entry_date   entry_day  \
# 0  981af824-236d-48e7-b8cc-f5849f9a7ad3 2026-02-06 18:36:00  2026-02-06
# 1  9256c5fc-b81b-4d7b-b186-9ab476288b11 2025-09-27 00:00:00  2025-09-27
# 2  81754f8e-da01-4725-a712-c31aa1c7b54a 2025-08-27 00:00:00  2025-08-27
# 3  745904e8-b8c8-4363-a5d9-5dc48162df64 2025-07-27 00:00:00  2025-07-27
# 4  ea59d13d-8ed6-49a2-b6e0-0f71c1b5513d 2025-06-27 00:00:00  2025-06-27
#
#   entry_month_start entry_month_year  entry_year  entry_month  \
# 0        2026-02-01          2026-02        2026            2
# 1        2025-09-01          2025-09        2025            9
# 2        2025-08-01          2025-08        2025            8
# 3        2025-07-01          2025-07        2025            7
# 4        2025-06-01          2025-06        2025            6
#
#                             branch_uuid   branch_name  \
# 0  c93efb5f-07c9-4229-b6b3-568ce1c0a9ab  สำนักงานใหญ่
# ...

# %%
query = """
SELECT *
FROM public.expense_category
ORDER BY category_name DESC
"""

df_expense_category = pd.read_sql(query, engine)

df_expense_category.head()
# Out:
#                category_name                         category_uuid
# 0                   ออนไลน์   3af0d8a1-e2e4-469c-9ac1-1fd9af58003a
# 1                สาธารณูปโภค  62a1a58b-bc96-4a43-9292-753512d57a7a
# 2                       ภาษี  ec0d6de1-baa2-4769-af99-202ef54f8200
# 3  บำรุงรักษาอุปกรณ์/ร้านค้า  9892ea30-cab9-457e-814a-019ac23acf36
# 4                   ดอกเบี้ย  11871e51-698b-41ac-b65b-315076136b4a

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_expense_general.to_csv("/content/drive/MyDrive/kcw_analytics/03_curated/fact_expense_general.csv", index=False, encoding="utf-8-sig")
df_expense_entries.to_csv("/content/drive/MyDrive/kcw_analytics/03_curated/fact_expense_entries.csv", index=False, encoding="utf-8-sig")
df_expense_category.to_csv("/content/drive/MyDrive/kcw_analytics/03_curated/dim_expense_category.csv", index=False, encoding="utf-8-sig")
