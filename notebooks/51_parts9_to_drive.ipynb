# %%
# !pip install sqlalchemy pyodbc

# %%
from sqlalchemy import create_engine
import pandas as pd
import urllib.parse

server = r'KSS'
database = 'PARTS9'
username = "python_reader"
password = "12345678" 

odbc_str = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    f"SERVER={server};"
    f"DATABASE={database};"
    f"UID={username};"
    f"PWD={password};"
    "TrustServerCertificate=yes;"
)

engine = create_engine("mssql+pyodbc:///?odbc_connect=" + urllib.parse.quote_plus(odbc_str))

# %%
df_sidet = pd.read_sql("SELECT * FROM dbo.SIDET;", engine)
df_pidet = pd.read_sql("SELECT * FROM dbo.PIDET;", engine)
df_simas = pd.read_sql("SELECT * FROM dbo.SIMAS;", engine)
df_pimas = pd.read_sql("SELECT * FROM dbo.PIMAS;", engine)
df_icmas = pd.read_sql("SELECT * FROM dbo.ICMAS;", engine)

# %%
import os

os.chdir(r"E:\.shortcut-targets-by-id\1ckHESSbV27WeJfNcwYueWhn9OqYkcW-t\01_raw")

# now you can save with short name
df_icmas.to_csv("raw_hq_icmas_products.csv", index=False, encoding="utf-8-sig")
df_pidet.to_csv("raw_hq_pidet_purchase_lines.csv", index=False, encoding="utf-8-sig")
df_pimas.to_csv("raw_hq_pimas_purchase_bills.csv", index=False, encoding="utf-8-sig")
df_sidet.to_csv("raw_hq_sidet_sales_lines.csv", index=False, encoding="utf-8-sig")
df_simas.to_csv("raw_hq_simas_sales_bills.csv", index=False, encoding="utf-8-sig")
